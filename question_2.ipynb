# %%
import pandas as pd
import xlrd
import os

# %% [markdown]
# # DATA EXPLORATION

# %%
workbook = xlrd.open_workbook("data-2/Dataset-2.xls", logfile=open(os.devnull, "w"))
dataset = pd.read_excel(workbook, sheet_name="Dataset-2")
video_length = pd.read_excel(workbook, sheet_name="Video Length - Prerecorded")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8968 entries, 0 to 8967
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         8968 non-null   datetime64[ns]
#  1   Lecture/Exercise  8968 non-null   object
#  2   Session Name      8968 non-null   object
#  3   Minutes Viewed    8968 non-null   float64
#  4   UserName          8968 non-null   object
#  5   Study Program     8968 non-null   object
#  6   Location          8968 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 490.6+ KB

# %%
video_length.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Session Name            16 non-null     object
#  1   Video Length (Minutes)  16 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 388.0+ bytes

# %%
# find unique values in the dataset session name
print(len(video_length['Session Name'].unique()))
# Out:
# 16

# %%
print(len(dataset['Session Name'].unique()))
# Out:
# 54

# %%
combined_data = pd.merge(dataset, video_length, on="Session Name", how="left")

# %%
combined_data[:30]
# Out:
#              Timestamp Lecture/Exercise              Session Name  \
# 0  2022-02-03 09:34:13        Lecture01  Lecture01_Practicalities
# 1  2022-02-03 09:35:10        Lecture01  Lecture01_Practicalities
# 2  2022-02-03 09:35:11        Lecture01  Lecture01_Practicalities
# 3  2022-02-03 09:36:46        Lecture01  Lecture01_Practicalities
# 4  2022-02-03 09:37:18        Lecture01  Lecture01_Practicalities
# 5  2022-02-03 09:39:26        Lecture01  Lecture01_Practicalities
# 6  2022-02-03 09:45:32        Lecture01  Lecture01_Practicalities
# 7  2022-02-03 09:48:43        Lecture01  Lecture01_Practicalities
# 8  2022-02-03 09:52:36        Lecture01  Lecture01_Practicalities
# 9  2022-02-03 09:52:36        Lecture01  Lecture01_Practicalities
# 10 2022-02-03 09:52:36        Lecture01  Lecture01_Practicalities
# 11 2022-02-03 09:52:36        Lecture01  Lecture01_Practicalities
# 12 2022-02-03 09:52:36        Lecture01  Lecture01_Practicalities
# ...
